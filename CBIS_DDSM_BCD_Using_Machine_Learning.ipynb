# %%
print(' Author : Yagnik Maheshbhai Poshiya \n Student ID : 20CE114 (20ce114@charusat.edu.in) \n Computer Engineering \n Chandubhai S. Patel Institute Of Technology, CHARUSAT, ANAND, GUJARAT.')
print(' Author : Nirmi Patel \n Student ID : 20CE114 (20ce095@charusat.edu.in) \n Computer Engineering \n Chandubhai S. Patel Institute Of Technology, CHARUSAT, ANAND, GUJARAT.')
print(' Author : Sapnil Patel \n Student ID : 20CE114 (20ce103@charusat.edu.in) \n Computer Engineering \n Chandubhai S. Patel Institute Of Technology, CHARUSAT, ANAND, GUJARAT.')
# Out:
#  Author : Yagnik Maheshbhai Poshiya
#  Student ID : 20CE114 (20ce114@charusat.edu.in)
#  Computer Engineering
#  Chandubhai S. Patel Institute Of Technology, CHARUSAT, ANAND, GUJARAT.
#  Author : Nirmi Patel
#  Student ID : 20CE114 (20ce095@charusat.edu.in)
#  Computer Engineering
#  Chandubhai S. Patel Institute Of Technology, CHARUSAT, ANAND, GUJARAT.
#  Author : Sapnil Patel
#  Student ID : 20CE114 (20ce103@charusat.edu.in)
#  Computer Engineering
#  Chandubhai S. Patel Institute Of Technology, CHARUSAT, ANAND, GUJARAT.

# %%
# importing libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading

# %%
dataFrame = pd.read_csv('/content/drive/MyDrive/BCD Structured Format/AttemptedDataset/CBIS-DDSM/Train-TestMergedCalcification.csv')

# %% [markdown]
# # Data Preprocessing

# %%
def ValueConversion():
  CalcTypeValues = [np.nan,'AMORPHOUS','PLEOMORPHIC','ROUND_AND_REGULAR-LUCENT_CENTER-DYSTROPHIC','PUNCTATE','COARSE','VASCULAR','FINE_LINEAR_BRANCHING','LARGE_RODLIKE','PUNCTATE-LUCENT_CENTER','VASCULAR-COARSE-LUCENT_CENTER-ROUND_AND_REGULAR-PUNCTATE','ROUND_AND_REGULAR-EGGSHELL','PUNCTATE-PLEOMORPHIC','PLEOMORPHIC-FINE_LINEAR_BRANCHING','DYSTROPHIC','LUCENT_CENTER','AMORPHOUS-PLEOMORPHIC','ROUND_AND_REGULAR','VASCULAR-COARSE-LUCENT_CENTERED','COARSE-ROUND_AND_REGULAR','COARSE-PLEOMORPHIC','LUCENT_CENTERED','VASCULAR-COARSE','ROUND_AND_REGULAR-PUNCTATE','ROUND_AND_REGULAR-LUCENT_CENTER','ROUND_AND_REGULAR-LUCENT_CENTERED','COARSE-ROUND_AND_REGULAR-LUCENT_CENTERED','COARSE-ROUND_AND_REGULAR-LUCENT_CENTER','SKIN','LUCENT_CENTER-PUNCTATE','SKIN-PUNCTATE','SKIN-PUNCTATE-ROUND_AND_REGULAR','MILK_OF_CALCIUM','PLEOMORPHIC-PLEOMORPHIC','SKIN-COARSE-ROUND_AND_REGULAR','AMORPHOUS-ROUND_AND_REGULAR','ROUND_AND_REGULAR-PLEOMORPHIC','ROUND_AND_REGULAR-PUNCTATE-AMORPHOUS','ROUND_AND_REGULAR-AMORPHOUS','LARGE_RODLIKE-ROUND_AND_REGULAR','ROUND_AND_REGULAR-LUCENT_CENTER-PUNCTATE','COARSE-LUCENT_CENTER','PUNCTATE-AMORPHOUS','PUNCTATE-ROUND_AND_REGULAR','EGGSHELL','LUCENT_CENTER','PUNCTATE-FINE_LINEAR_BRANCHING','PUNCTATE-AMORPHOUS-PLEOMORPHIC','PLEOMORPHIC-AMORPHOUS']
  for iterVar_Three in range(0,len(CalcTypeValues)):
    dataFrame['calc type'] = dataFrame['calc type'].replace([CalcTypeValues[iterVar_Three]],iterVar_Three)

  CalcDistributionValues = [np.nan,'CLUSTERED','REGIONAL','LINEAR','DIFFUSELY_SCATTERED','SEGMENTAL','CLUSTERED-LINEAR','CLUSTERED-SEGMENTAL','LINEAR-SEGMENTAL','REGIONAL-REGIONAL']
  for iterVar_Four in range(0,len(CalcDistributionValues)):
    dataFrame['calc distribution'] = dataFrame['calc distribution'].replace([CalcDistributionValues[iterVar_Four]],iterVar_Four)

# %%
ValueConversion()

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

dataFrame
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 4       P_00008               1                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1867    P_02464               2                RIGHT        MLO
# 1868    P_02498               4                RIGHT         CC
# 1869    P_02498               4                RIGHT        MLO
# 1870    P_02501               3                RIGHT         CC
# 1871    P_02501               3                RIGHT        MLO
#
#       abnormality id abnormality type  calc type  calc distribution  \
# 0                  1    calcification          1                  1
# 1                  1    calcification          1                  1
# 2                  1    calcification          2                  3
# 3                  1    calcification          2                  3
# 4                  1    calcification          0                  2
# ...              ...              ...        ...                ...
# 1867               1    calcification          7                  1
# 1868               1    calcification          4                  1
# 1869               1    calcification          4                  1
# 1870               1    calcification          2                  1
# 1871               1    calcification          2                  1
#
#       assessment  subtlety                pathology
# 0              3         3                MALIGNANT
# 1              3         3                MALIGNANT
# 2              4         4                   BENIGN
# 3              4         4                   BENIGN
# 4              2         3  BENIGN_WITHOUT_CALLBACK
# ...          ...       ...                      ...
# 1867           0         4                MALIGNANT
# 1868           0         3                   BENIGN
# 1869           0         3                   BENIGN
# 1870           0         3                MALIGNANT
# 1871           0         3                MALIGNANT
#
# [1872 rows x 11 columns]

# %%
dataFrame['left or right breast'] = dataFrame['left or right breast'].replace(['RIGHT','LEFT'],[82,76])
dataFrame['image view'] = dataFrame['image view'].replace(['CC','MLO'],[67,77])
dataFrame['abnormality type'] = dataFrame['abnormality type'].replace(['calcification'],99)
dataFrame['pathology'] = dataFrame['pathology'].replace(['BENIGN_WITHOUT_CALLBACK','BENIGN','MALIGNANT'],[0,1,2])
dataFrame
# Out:
#      patient_id  breast density  left or right breast  image view  \
# 0       P_00005               3                    82          67
# 1       P_00005               3                    82          77
# 2       P_00007               4                    76          67
# 3       P_00007               4                    76          77
# 4       P_00008               1                    76          67
# ...         ...             ...                   ...         ...
# 1867    P_02464               2                    82          77
# 1868    P_02498               4                    82          67
# 1869    P_02498               4                    82          77
# 1870    P_02501               3                    82          67
# 1871    P_02501               3                    82          77
#
#       abnormality id  abnormality type  calc type  calc distribution  \
# 0                  1                99          1                  1
# 1                  1                99          1                  1
# 2                  1                99          2                  3
# 3                  1                99          2                  3
# 4                  1                99          0                  2
# ...              ...               ...        ...                ...
# 1867               1                99          7                  1
# 1868               1                99          4                  1
# 1869               1                99          4                  1
# 1870               1                99          2                  1
# 1871               1                99          2                  1
#
#       assessment  subtlety  pathology
# 0              3         3          2
# 1              3         3          2
# 2              4         4          1
# 3              4         4          1
# 4              2         3          0
# ...          ...       ...        ...
# 1867           0         4          2
# 1868           0         3          1
# 1869           0         3          1
# 1870           0         3          2
# 1871           0         3          2
#
# [1872 rows x 11 columns]

# %%
# Counting total number of rows and columns
dataFrame.shape
# Out:
# (1872, 11)

# %%
# Counting total number of empty (NaN, NAN, na) values in each column
dataFrame.isna().sum()
# Out:
# patient_id              0
# breast density          0
# left or right breast    0
# image view              0
# abnormality id          0
# abnormality type        0
# calc type               0
# calc distribution       0
# assessment              0
# subtlety                0
# pathology               0
# dtype: int64

# %%
dataFrame['pathology'].value_counts()
# Out:
# 2    673
# 1    658
# 0    541
# Name: pathology, dtype: int64

# %%
sns.countplot(dataFrame['pathology'],label='Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patient_id            1872 non-null   object
#  1   breast density        1872 non-null   int64
#  2   left or right breast  1872 non-null   int64
#  3   image view            1872 non-null   int64
#  4   abnormality id        1872 non-null   int64
#  5   abnormality type      1872 non-null   int64
#  6   calc type             1872 non-null   int64
#  7   calc distribution     1872 non-null   int64
#  8   assessment            1872 non-null   int64
#  9   subtlety              1872 non-null   int64
#  10  pathology             1872 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 161.0+ KB

# %%
dataFrame.head()
# Out:
#   patient_id  breast density  left or right breast  image view  \
# 0    P_00005               3                    82          67
# 1    P_00005               3                    82          77
# 2    P_00007               4                    76          67
# 3    P_00007               4                    76          77
# 4    P_00008               1                    76          67
#
#    abnormality id  abnormality type  calc type  calc distribution  assessment  \
# 0               1                99          1                  1           3
# 1               1                99          1                  1           3
# 2               1                99          2                  3           4
# 3               1                99          2                  3           4
# 4               1                99          0                  2           2
#
#    subtlety  pathology
# 0         3          2
# 1         3          2
# 2         4          1
# 3         4          1
# 4         3          0

# %% [markdown]
# # Finding Correlation

# %%
dataFrame.iloc[:,1:10].corr()
# Out:
#                       breast density  left or right breast  image view  \
# breast density              1.000000             -0.019907    0.019938
# left or right breast       -0.019907              1.000000    0.005775
# image view                  0.019938              0.005775    1.000000
# abnormality id             -0.115227              0.026486    0.008454
# abnormality type                 NaN                   NaN         NaN
# calc type                  -0.024985             -0.022245   -0.011869
# calc distribution           0.150174             -0.065890    0.007404
# assessment                  0.173373             -0.030351    0.013942
# subtlety                   -0.235975              0.050863   -0.018092
#
#                       abnormality id  abnormality type  calc type  \
# breast density             -0.115227               NaN  -0.024985
# left or right breast        0.026486               NaN  -0.022245
# image view                  0.008454               NaN  -0.011869
# abnormality id              1.000000               NaN   0.283970
# abnormality type                 NaN               NaN        NaN
# calc type                   0.283970               NaN   1.000000
# calc distribution          -0.085961               NaN  -0.148662
# assessment                 -0.249841               NaN  -0.427340
# subtlety                    0.222361               NaN   0.250090
#
#                       calc distribution  assessment  subtlety
# breast density                 0.150174    0.173373 -0.235975
# left or right breast          -0.065890   -0.030351  0.050863
# image view                     0.007404    0.013942 -0.018092
# abnormality id                -0.085961   -0.249841  0.222361
# abnormality type                    NaN         NaN       NaN
# calc type                     -0.148662   -0.427340  0.250090
# calc distribution              1.000000    0.332995 -0.055031
# assessment                     0.332995    1.000000 -0.126625
# subtlety                      -0.055031   -0.126625  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dataFrame.iloc[:,1:10].corr(), annot=True, fmt='.0%')

# %% [markdown]
# # Splitting Dataset Into Training and Testing Set

# %%
# Spilting Dataset into input(X) and output(Y)
X = dataFrame.iloc[:,1:10].values
Y = dataFrame.iloc[:,10].values
print(X)
print(Y)
# Out:
# [[ 3 82 67 ...  1  3  3]
#  [ 3 82 77 ...  1  3  3]
#  [ 4 76 67 ...  3  4  4]
#  ...
#  [ 4 82 77 ...  1  0  3]
#  [ 3 82 67 ...  1  0  3]
#  [ 3 82 77 ...  1  0  3]]
# [2 2 1 ... 1 2 2]

# %%
# spliting Dataset into training and testing based on input(X) and output(Y)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.25,random_state=0)

# %% [markdown]
# # Applying Standard Scaler Process On Data

# %%
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
X_train = standardScaler.fit_transform(X_train)
X_test = standardScaler.fit_transform(X_test)
print(X_train)
print(X_test)
# Out:
# [[-0.72192099  1.06173101  0.9432055  ... -0.30563455 -2.64447162
#   -1.17653442]
#  [-1.80134279 -0.94185815 -1.06021435 ... -0.30563455  1.39913343
#    1.37131287]
#  [-1.80134279 -0.94185815  0.9432055  ... -0.92306032 -1.0270296
#    1.37131287]
#  ...
#  [ 0.35750081 -0.94185815  0.9432055  ...  2.16406853  0.59041242
#   -1.17653442]
#  [-0.72192099 -0.94185815  0.9432055  ...  0.31179122  1.39913343
#    1.37131287]
#  [ 0.35750081  1.06173101  0.9432055  ... -0.30563455  0.59041242
#    0.52203044]]
# [[ 1.40074459 -0.90219371 -1.03037566 ...  1.75586604 -1.15142818
#   -0.35687906]
#  [ 1.40074459 -0.90219371 -1.03037566 ... -0.40662161  0.54046629
#    0.48241441]
#  [ 0.34680815  1.10840941  0.97051982 ... -0.40662161  0.54046629
#    0.48241441]
#  ...
#  [ 0.34680815 -0.90219371 -1.03037566 ... -0.40662161  0.54046629
#   -2.03546599]
#  [ 0.34680815 -0.90219371  0.97051982 ...  0.1340003  -1.15142818
#    1.32170787]
#  [-0.7071283  -0.90219371  0.97051982 ... -0.94724352 -1.15142818
#    1.32170787]]

# %% [markdown]
# # Testing Various Models On Training and Testing Set

# %%
# defining function to try various models on dataset
def TestableModels(X_train, Y_train):
  # Logistic Regression Model
  from sklearn.linear_model import LogisticRegression
  LR = LogisticRegression(random_state=0)
  LR.fit(X_train, Y_train)

  # Decision Tree Model
  from sklearn.tree import DecisionTreeClassifier
  Tree = DecisionTreeClassifier(criterion='entropy', random_state=0)
  Tree.fit(X_train, Y_train)

  # Random Forest Classifier
  from sklearn.ensemble import RandomForestClassifier
  RFC = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)
  RFC.fit(X_train, Y_train)
  
  # Support Vector Machine 
  from sklearn import svm
  SupportVectorClassifier = svm.SVC()
  SupportVectorClassifier.fit(X_train, Y_train)

  # Multilayer Perceptron
  from sklearn.neural_network import MLPClassifier
  MultilayerPerceptron = MLPClassifier(solver='lbfgs', alpha=0.1, hidden_layer_sizes=(5,2), random_state=1)
  MultilayerPerceptron.fit(X_train, Y_train)

   # Printing accuracy of model on training data
  print('[0] Logistic Regression Training Accuracy : ', LR.score(X_train, Y_train))
  print('[1] Decision Tree Training Accuracy : ', Tree.score(X_train, Y_train))
  print('[2] Random Forest Training Accuracy : ', RFC.score(X_train, Y_train))
  print('[3] Support Vector Machine Training Accuracy : ', SupportVectorClassifier.score(X_train, Y_train))
  print('[4] Multilayer Perceptron Training Accuracy : ', MultilayerPerceptron.score(X_train, Y_train))

  # returning values of LR, Tree and RFC
  return LR,Tree,RFC,SupportVectorClassifier,MultilayerPerceptron

# %%
model = TestableModels(X_train, Y_train)
# Out:
# [0] Logistic Regression Training Accuracy :  0.6951566951566952
# [1] Decision Tree Training Accuracy :  0.9109686609686609
# [2] Random Forest Training Accuracy :  0.9009971509971509
# [3] Support Vector Machine Training Accuracy :  0.7970085470085471
# [4] Multilayer Perceptron Training Accuracy :  0.6602564102564102
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %% [markdown]
# # Generating Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
for iterVar_One in range(len(model)):
  ConfusionMatrix = confusion_matrix(Y_test, model[iterVar_One].predict(X_test))
  TruePositive = ConfusionMatrix[0][0]
  TrueNegative = ConfusionMatrix[1][1]
  FalsePositive = ConfusionMatrix[0][1]
  FalseNegative = ConfusionMatrix[1][0]
  print('-------------> Confusion Matrix : ',TruePositive, TrueNegative, FalseNegative, FalsePositive)
  print([iterVar_One],'Testing Accuracy Of Model ',[iterVar_One],(TruePositive+TrueNegative)/(TruePositive+TrueNegative+FalsePositive+FalseNegative))
# Out:
# -------------> Confusion Matrix :  118 86 26 5
# [0] Testing Accuracy Of Model  [0] 0.8680851063829788
# -------------> Confusion Matrix :  124 128 1 0
# [1] Testing Accuracy Of Model  [1] 0.9960474308300395
# -------------> Confusion Matrix :  122 120 1 2
# [2] Testing Accuracy Of Model  [2] 0.9877551020408163
# -------------> Confusion Matrix :  123 116 13 1
# [3] Testing Accuracy Of Model  [3] 0.9446640316205533
# -------------> Confusion Matrix :  117 6 9 5
# [4] Testing Accuracy Of Model  [4] 0.8978102189781022

# %% [markdown]
# # Generating Classification Report

# %%
# getting classification report
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
for iterVar_Two in range(len(model)):
  print('---------Model---------',iterVar_Two)
  print(classification_report(Y_test,model[iterVar_Two].predict(X_test)))
  print(accuracy_score(Y_test,model[iterVar_Two].predict(X_test)))
  print('\n')
# Out:
# ---------Model--------- 0
#               precision    recall  f1-score   support
#
#            0       0.77      0.95      0.85       124
#            1       0.48      0.53      0.51       162
#            2       0.63      0.47      0.54       182
#
#     accuracy                           0.62       468
#    macro avg       0.63      0.65      0.63       468
# weighted avg       0.62      0.62      0.61       468
#
# 0.6196581196581197
#
#
# ---------Model--------- 1
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       124
#            1       0.66      0.79      0.72       162
#            2       0.78      0.63      0.69       182
#
#     accuracy                           0.78       468
#    macro avg       0.81      0.81      0.80       468
# weighted avg       0.79      0.78      0.78       468
#
# 0.782051282051282
#
#
# ---------Model--------- 2
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       124
#            1       0.66      0.74      0.70       162
#            2       0.75      0.66      0.70       182
#
#     accuracy                           0.77       468
#    macro avg       0.79      0.79      0.79       468
# weighted avg       0.78      0.77      0.77       468
#
# 0.7735042735042735
#
#
# ---------Model--------- 3
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       124
#            1       0.55      0.72      0.62       162
#            2       0.72      0.48      0.58       182
#
#     accuracy                           0.70       468
#    macro avg       0.72      0.73      0.71       468
# weighted avg       0.71      0.70      0.69       468
#
# 0.6965811965811965
#
#
# ---------Model--------- 4
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       124
#            1       0.32      0.04      0.07       162
#            2       0.54      0.95      0.68       182
#
#     accuracy                           0.63       468
#    macro avg       0.59      0.64      0.56       468
# weighted avg       0.56      0.63      0.53       468
#
# 0.6303418803418803

# %% [markdown]
# # Comparing Predicted and Actual Values

# %%
# Now to see predicted values of any of model (Here i have taken random forest classifier)
PredictionValues = model[4].predict(X_test)
print(PredictionValues)
print('\n\n\n',Y_test)
# Out:
# [0 2 2 0 0 1 2 0 0 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 0 0 2 2 0 0 0 0 0 2 2 2
#  2 2 2 0 2 2 0 2 2 2 2 2 2 2 0 2 2 0 2 2 2 0 0 2 2 2 0 1 2 2 2 2 0 2 2 2 2
#  2 2 2 2 0 2 0 2 2 2 2 2 2 0 0 2 2 2 2 2 2 2 2 0 0 2 2 2 2 2 2 2 2 2 2 0 0
#  2 2 2 2 2 2 2 2 2 2 2 1 2 0 2 2 2 2 0 2 2 1 2 0 2 0 2 2 0 2 2 2 1 0 0 1 2
#  0 2 2 0 2 2 2 0 2 0 2 0 2 1 2 0 2 2 0 0 2 0 2 2 2 2 0 0 2 2 0 2 0 2 2 2 1
#  2 2 2 0 2 2 2 0 2 2 2 2 2 0 0 2 2 2 2 0 2 2 0 2 2 2 2 2 2 2 2 0 2 2 2 2 2
#  0 2 0 2 2 2 0 2 2 0 2 0 2 0 2 2 0 1 2 2 2 2 0 0 0 2 0 2 2 0 2 2 2 2 2 2 0
#  0 0 2 2 0 0 2 0 2 2 2 2 1 1 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 0 2 2 2 2 2 0 2
#  2 2 2 2 2 0 2 0 2 2 2 2 2 0 2 2 2 1 2 2 2 2 2 2 2 0 0 2 2 2 2 2 2 0 0 2 2
#  0 2 2 0 2 2 2 2 2 2 0 2 2 1 2 2 0 0 1 2 2 2 2 2 2 0 2 2 2 2 2 2 0 2 2 2 2
#  0 0 2 2 1 2 2 0 2 0 2 0 2 2 2 0 2 2 0 2 2 2 2 2 2 2 2 0 2 0 0 2 0 0 2 0 0
#  2 0 0 2 2 0 2 2 2 2 0 0 0 2 1 0 2 2 2 0 0 2 0 2 0 2 0 2 2 0 2 2 2 2 2 2 2
#  0 2 1 2 0 2 2 2 0 0 2 0 2 1 2 2 0 2 0 2 1 2 0 0]
#
#
#
#  [1 1 2 0 0 2 2 0 1 2 1 2 2 2 1 2 2 2 0 1 1 1 1 2 1 0 0 2 2 0 0 0 0 0 2 1 1
#  1 1 2 2 2 1 0 2 1 1 1 2 1 1 0 2 1 0 2 1 2 0 1 1 2 2 0 1 2 1 2 1 2 2 2 1 1
#  2 2 1 2 0 2 0 2 1 2 2 2 1 0 0 1 2 2 2 1 1 2 1 0 0 2 2 2 1 1 1 1 2 1 1 0 0
#  1 2 2 2 2 2 1 1 2 2 1 1 1 0 2 2 1 2 0 2 1 0 1 0 2 0 2 1 0 1 2 2 2 0 0 0 1
#  0 2 2 0 2 1 1 0 1 0 2 0 2 1 1 0 1 1 0 0 1 0 2 2 1 1 0 0 2 1 0 1 0 2 2 2 2
#  2 1 2 0 2 1 1 0 1 2 1 2 1 0 0 1 1 2 2 1 2 1 0 2 1 2 2 2 2 2 1 0 2 1 1 1 1
#  0 2 0 1 1 1 1 2 1 0 0 0 1 0 1 2 0 1 1 2 2 2 0 0 0 1 0 2 2 0 1 2 1 1 2 1 0
#  0 0 1 2 0 0 2 0 1 2 2 1 2 0 0 2 2 2 2 1 2 1 0 1 1 2 1 1 1 0 2 2 2 1 1 0 2
#  1 2 2 2 2 0 1 0 2 2 2 1 2 1 2 1 1 1 2 1 2 2 1 2 1 0 0 2 1 1 2 1 2 0 0 1 2
#  0 1 1 0 1 1 1 2 1 1 0 1 1 2 2 1 0 0 0 1 2 2 2 2 2 0 1 2 2 2 2 2 0 2 1 2 2
#  0 0 1 2 0 2 1 0 1 0 2 0 2 1 1 0 2 1 0 2 2 1 2 1 2 2 2 0 2 1 0 2 0 0 1 0 0
#  2 0 0 1 2 0 2 1 1 1 0 0 0 1 2 1 1 2 1 0 0 2 0 2 0 2 0 1 1 0 2 2 2 2 0 2 1
#  1 2 2 1 0 2 1 2 0 0 2 0 1 2 2 2 0 2 0 2 1 1 0 0]

# %% [markdown]
# # Applying Cross Validation

# %%
import numpy as np
from sklearn.model_selection import KFold

X = np.array(X_train)
y = np.array(Y_train)
kf = KFold(n_splits=5)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.neural_network import MLPClassifier

# %%
models_name = ['Logistic Regression','Decision Tree','Random Forest','Support Vector Machine','Multilayer Perceptron']

# %%
for train_index, test_index in kf.split(X):
    # print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    CV_score_LR = cross_val_score(LogisticRegression(random_state=0), X_train, y_train, cv=3)
    print('[0] Logistic Regression CV Score------>',CV_score_LR)
    print('   Average CV Score------>',np.average(CV_score_LR))

    CV_score_DT = cross_val_score(DecisionTreeClassifier(criterion='entropy', random_state=0), X_train, y_train, cv=3)
    print('[1] Decision Tree CV Score------>',CV_score_DT)
    print('   Average CV Score------>',np.average(CV_score_DT))

    CV_score_RF = cross_val_score(RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0), X_train, y_train, cv=3)
    print('[2] Random Forest CV Score------>',CV_score_RF)
    print('   Average CV Score------>',np.average(CV_score_RF))

    CV_score_SVM = cross_val_score(svm.SVC(), X_train, y_train, cv=3)
    print('[3] Support Vector Machine CV Score------>',CV_score_SVM)
    print('   Average CV Score------>',np.average(CV_score_SVM))

    CV_score_MLP = cross_val_score(MLPClassifier(solver='lbfgs', alpha=0.1, hidden_layer_sizes=(5,2), random_state=1), X_train, y_train, cv=3)
    print('[4] Multilayer Perceptron CV Score------>',CV_score_MLP)
    print('   Average CV Score------>',np.average(CV_score_MLP))

    print('\n------------------------------------------------------------------------------------------\n')
# Out:
# [0] Logistic Regression CV Score------> [0.70933333 0.68983957 0.68181818]
#    Average CV Score------> 0.6936636957813428
# [1] Decision Tree CV Score------> [0.75466667 0.78074866 0.75935829]
#    Average CV Score------> 0.7649245395127747
# [2] Random Forest CV Score------> [0.77333333 0.78877005 0.73262032]
#    Average CV Score------> 0.7649079025549614
# [3] Support Vector Machine CV Score------> [0.784      0.76203209 0.70320856]
#    Average CV Score------> 0.74974688057041
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [4] Multilayer Perceptron CV Score------> [0.64       0.65240642 0.64705882]
#    Average CV Score------> 0.6464884135472371
#
# ------------------------------------------------------------------------------------------
#
# [0] Logistic Regression CV Score------> [0.63466667 0.65240642 0.62566845]
#    Average CV Score------> 0.6375805109922758
# [1] Decision Tree CV Score------> [0.768      0.76203209 0.73796791]
#    Average CV Score------> 0.7559999999999999
# [2] Random Forest CV Score------> [0.76266667 0.74331551 0.73529412]
#    Average CV Score------> 0.7470920974450387
# [3] Support Vector Machine CV Score------> [0.72266667 0.7486631  0.68716578]
#    Average CV Score------> 0.7194985145573382
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [4] Multilayer Perceptron CV Score------> [0.62133333 0.64973262 0.63903743]
#    Average CV Score------> 0.6367011289364232
#
# ------------------------------------------------------------------------------------------
#
# [0] Logistic Regression CV Score------> [0.65333333 0.65775401 0.62834225]
#    Average CV Score------> 0.6464765300059417
# [1] Decision Tree CV Score------> [0.75466667 0.7513369  0.73262032]
#    Average CV Score------> 0.7462079619726678
# [2] Random Forest CV Score------> [0.76533333 0.7486631  0.71390374]
#    Average CV Score------> 0.7426333927510398
# [3] Support Vector Machine CV Score------> [0.73066667 0.77807487 0.70320856]
#    Average CV Score------> 0.7373166963755199
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [4] Multilayer Perceptron CV Score------> [0.62933333 0.64973262 0.64171123]
#    Average CV Score------> 0.6402590612002377
#
# ------------------------------------------------------------------------------------------
#
# [0] Logistic Regression CV Score------> [0.648      0.7459893  0.64705882]
#    Average CV Score------> 0.6803493761140821
# [1] Decision Tree CV Score------> [0.75733333 0.78877005 0.75668449]
#    Average CV Score------> 0.7675959595959596
# [2] Random Forest CV Score------> [0.77066667 0.79679144 0.74331551]
#    Average CV Score------> 0.7702578728461081
# [3] Support Vector Machine CV Score------> [0.73333333 0.78609626 0.71657754]
#    Average CV Score------> 0.7453357100415925
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [4] Multilayer Perceptron CV Score------> [0.63733333 0.66042781 0.64171123]
#    Average CV Score------> 0.6464907902554962
#
# ------------------------------------------------------------------------------------------
#
# [0] Logistic Regression CV Score------> [0.66666667 0.72       0.68181818]
#    Average CV Score------> 0.6894949494949495
# [1] Decision Tree CV Score------> [0.736      0.808      0.75935829]
#    Average CV Score------> 0.7677860962566845
# [2] Random Forest CV Score------> [0.73066667 0.808      0.76203209]
#    Average CV Score------> 0.7668995840760547
# [3] Support Vector Machine CV Score------> [0.736      0.77866667 0.73262032]
#    Average CV Score------> 0.7490956625074272
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [4] Multilayer Perceptron CV Score------> [0.62933333 0.63733333 0.64705882]
#    Average CV Score------> 0.6379084967320261
#
# ------------------------------------------------------------------------------------------
